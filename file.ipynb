# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5)
df
# Out:
#    sn     name  age    address      phone
# 0   1      Ram   34  Kathmandu  823894893
# 1   2    Shyam   24    Chitwan   24545456
# 2   3  Krishna   44  Bhaktapur    2434554
# 3   4     Hari   21      Patan  243456546
# 4   5      Raj   32   Nawalpur    3435636

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#    sn     name  age    address      phone
# 0   1      Ram   34  Kathmandu  823894893
# 1   2    Shyam   24    Chitwan   24545456
# 2   3  Krishna   44  Bhaktapur    2434554
# 3   4     Hari   21      Patan  243456546
# 4   5      Raj   32   Nawalpur    3435636

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.tail()
# Out:
#    sn     name  age    address      phone
# 0   1      Ram   34  Kathmandu  823894893
# 1   2    Shyam   24    Chitwan   24545456
# 2   3  Krishna   44  Bhaktapur    2434554
# 3   4     Hari   21      Patan  243456546
# 4   5      Raj   32   Nawalpur    3435636

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.head() #practice using head(2)
# Out:
#        name  age    address      phone
# sn
# 1       Ram   34  Kathmandu  823894893
# 2     Shyam   24    Chitwan   24545456
# 3   Krishna   44  Bhaktapur    2434554
# 4      Hari   21      Patan  243456546
# 5       Raj   32   Nawalpur    3435636

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn',usecols = ['sn','name','phone'])
df.head()
# Out:
#        name      phone
# sn
# 1       Ram  823894893
# 2     Shyam   24545456
# 3   Krishna    2434554
# 4      Hari  243456546
# 5       Raj    3435636

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.iloc[1:4,0:3]
# Out:
#        name  age    address
# sn
# 2     Shyam   24    Chitwan
# 3   Krishna   44  Bhaktapur
# 4      Hari   21      Patan

# %%
#euta data bata aarko data herna cha vane we use lock
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.loc[1:4]
# Out:
#        name  age    address      phone
# sn
# 1       Ram   34  Kathmandu  823894893
# 2     Shyam   24    Chitwan   24545456
# 3   Krishna   44  Bhaktapur    2434554
# 4      Hari   21      Patan  243456546

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name') #index_col ko value unique huna parcha
df.loc['Ram':'Hari']
# Out:
#          sn  age    address      phone
# name
# Ram       1   34  Kathmandu  823894893
# Shyam     2   24    Chitwan   24545456
# Krishna   3   44  Bhaktapur    2434554
# Hari      4   21      Patan  243456546

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df[df['name'] == 'Shyam']
# Out:
#      name  age  address     phone
# sn
# 2   Shyam   24  Chitwan  24545456

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df[df['age']>40]
# Out:
#        name  age    address    phone
# sn
# 3   Krishna   44  Bhaktapur  2434554

# %%
type(list(df['age'])[0])
# Out:
# int

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
data = df[df['age']>30]
data.to_csv('new_data.csv')

# %%
#multiple conditions
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
data = df[(df['age']>20) & (df['address']=='Kathmandu')]
data
# Out:
#    name  age    address      phone
# sn
# 1   Ram   34  Kathmandu  823894893

# %%
import pandas
d = {'sn':[1,2],
     'product':['momo','coke'],
     'price':[120,50],
     'quantity':[2,4],
     'total':[240,200]}
df = pd.DataFrame(d)
df
# Out:
#    sn product  price  quantity  total
# 0   1    momo    120         2    240
# 1   2    coke     50         4    200

# %%
import pandas
data = [[1,'momo',120,2,240],
        [2,'coke',50,4,200]]
with open()
